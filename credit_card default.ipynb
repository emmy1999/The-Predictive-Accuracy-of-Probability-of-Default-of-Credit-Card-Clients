# %%
# importing libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#pip install xlrd

# %%
# Loading the dataset from excel file and skip first row
data = pd.read_excel('default of credit card clients.xls', skiprows=1)

# %%
data
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24      2      2     -1
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
# ...

# %%
# Check data types 
data.dtypes
# Out:
# ID                            int64
# LIMIT_BAL                     int64
# SEX                           int64
# EDUCATION                     int64
# MARRIAGE                      int64
# AGE                           int64
# PAY_0                         int64
# PAY_2                         int64
# PAY_3                         int64
# PAY_4                         int64
# PAY_5                         int64
# PAY_6                         int64
# BILL_AMT1                     int64
# BILL_AMT2                     int64
# BILL_AMT3                     int64
# BILL_AMT4                     int64
# BILL_AMT5                     int64
# BILL_AMT6                     int64
# PAY_AMT1                      int64
# PAY_AMT2                      int64
# PAY_AMT3                      int64
# PAY_AMT4                      int64
# PAY_AMT5                      int64
# PAY_AMT6                      int64
# default payment next month    int64
# dtype: object

# %%
# Displaying the first few rows of the dataset to understand its structure.
print(data.head())
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
# Checking for missing values
print("\nMissing values present in the dataset :")
print(data.isnull().sum())
# Out:
# Missing values present in the dataset :
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64

# %%
# Rename columns for more clarity
data.columns = ['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_1', 'PAY_2', 'PAY_3', 
              'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 
              'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 
              'PAY_AMT6', 'default_payment_next_month']

# %%
# drop first attribute "ID"
data.drop('ID', axis = 1, inplace =True)
# Class label to category
data["default_payment_next_month"] = data["default_payment_next_month"].astype('category')
data["SEX"] = data["SEX"].astype('category')
data["EDUCATION"] = data["EDUCATION"].astype('category')
data["MARRIAGE"] = data["MARRIAGE"].astype('category')
data["PAY_1"] = data["PAY_1"].astype('category')
data["PAY_2"] = data["PAY_2"].astype('category')
data["PAY_3"] = data["PAY_3"].astype('category')
data["PAY_4"] = data["PAY_4"].astype('category')
data["PAY_5"] = data["PAY_5"].astype('category')
data["PAY_6"] = data["PAY_6"].astype('category')

# %%
# Displaying info about the dataset.
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   LIMIT_BAL                   30000 non-null  int64
#  1   SEX                         30000 non-null  category
#  2   EDUCATION                   30000 non-null  category
#  3   MARRIAGE                    30000 non-null  category
#  4   AGE                         30000 non-null  int64
#  5   PAY_1                       30000 non-null  category
#  6   PAY_2                       30000 non-null  category
#  7   PAY_3                       30000 non-null  category
#  8   PAY_4                       30000 non-null  category
#  9   PAY_5                       30000 non-null  category
#  10  PAY_6                       30000 non-null  category
#  11  BILL_AMT1                   30000 non-null  int64
#  12  BILL_AMT2                   30000 non-null  int64
# ...

# %%
data.head(10)
# Out:
#    LIMIT_BAL SEX EDUCATION MARRIAGE  AGE PAY_1 PAY_2 PAY_3 PAY_4 PAY_5  ...  \
# 0      20000   2         2        1   24     2     2    -1    -1    -2  ...
# 1     120000   2         2        2   26    -1     2     0     0     0  ...
# 2      90000   2         2        2   34     0     0     0     0     0  ...
# 3      50000   2         2        1   37     0     0     0     0     0  ...
# 4      50000   1         2        1   57    -1     0    -1     0     0  ...
# 5      50000   1         1        2   37     0     0     0     0     0  ...
# 6     500000   1         1        2   29     0     0     0     0     0  ...
# 7     100000   2         2        2   23     0    -1    -1     0     0  ...
# 8     140000   2         3        1   28     0     0     2     0     0  ...
# 9      20000   1         3        2   35    -2    -2    -2    -2    -1  ...
#
#   BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  \
# ...

# %%
# Distribution of categorical variables
print("\nDistribution of categorical variables:")
print("Sex:")
print(data['SEX'].value_counts())
print("\nEducation:")
print(data['EDUCATION'].value_counts())
print("\nMarriage:")
print(data['MARRIAGE'].value_counts())

print("\nPAY_1:")
print(data['PAY_1'].value_counts())

print("\nPAY_2:")
print(data['PAY_2'].value_counts())

print("\nPAY_3:")
print(data['PAY_3'].value_counts())

print("\nPAY_4:")
print(data['PAY_4'].value_counts())

print("\nPAY_5:")
print(data['PAY_5'].value_counts())

print("\nPAY_6:")
print(data['PAY_6'].value_counts())
# Out:
# Distribution of categorical variables:
# Sex:
# 2    18112
# 1    11888
# Name: SEX, dtype: int64
#
# Education:
# 2    14030
# 1    10585
# 3     4917
# 5      280
# 4      123
# 6       51
# 0       14
# Name: EDUCATION, dtype: int64
#
# Marriage:
# 2    15964
# 1    13659
# 3      323
# 0       54
# Name: MARRIAGE, dtype: int64
#
# PAY_1:
# 0     14737
# -1     5686
# 1      3688
# -2     2759
# 2      2667
# 3       322
# 4        76
# 5        26
# 8        19
# 6        11
# 7         9
# Name: PAY_1, dtype: int64
#
# PAY_2:
# 0     15730
# -1     6050
# 2      3927
# -2     3782
# 3       326
# 4        99
# 1        28
# 5        25
# 7        20
# 6        12
# 8         1
# Name: PAY_2, dtype: int64
#
# PAY_3:
# 0     15764
# -1     5938
# -2     4085
# 2      3819
# 3       240
# 4        76
# 7        27
# 6        23
# 5        21
# 1         4
# 8         3
# Name: PAY_3, dtype: int64
#
# PAY_4:
# 0     16455
# -1     5687
# -2     4348
# 2      3159
# 3       180
# ...

# %%
# category '0' undocumented is deleted
data = data.drop(data[data['MARRIAGE']==0].index)
# categories 0, 5 and 6 are unknown and are deleted
data = data.drop(data[data['EDUCATION']==0].index)
data = data.drop(data[data['EDUCATION']==5].index)
data = data.drop(data[data['EDUCATION']==6].index)

# %%
print("\nEducation:")
print(data['EDUCATION'].value_counts())
print("\nMarriage:")
print(data['MARRIAGE'].value_counts())
# Out:
# Education:
# 2    14024
# 1    10581
# 3     4873
# 4      123
# 0        0
# 5        0
# 6        0
# Name: EDUCATION, dtype: int64
#
# Marriage:
# 2    15806
# 1    13477
# 3      318
# 0        0
# Name: MARRIAGE, dtype: int64

# %%
# Distribution of target variable
print("\nDistribution of target variable:")
print(data['default_payment_next_month'].value_counts())
# Out:
# Distribution of target variable:
# 0    22996
# 1     6605
# Name: default_payment_next_month, dtype: int64

# %%
#Displaying Summary statistics
data.describe()
# Out:
#             LIMIT_BAL           AGE      BILL_AMT1      BILL_AMT2  \
# count    29601.000000  29601.000000   29601.000000   29601.000000
# mean    167550.544914     35.464072   50957.432012   48942.189554
# std     129944.020953      9.213243   73370.242404   70923.985151
# min      10000.000000     21.000000 -165580.000000  -69777.000000
# 25%      50000.000000     28.000000    3528.000000    2970.000000
# 50%     140000.000000     34.000000   22259.000000   21050.000000
# 75%     240000.000000     41.000000   66623.000000   63497.000000
# max    1000000.000000     79.000000  964511.000000  983931.000000
#
#           BILL_AMT3      BILL_AMT4      BILL_AMT5      BILL_AMT6  \
# count  2.960100e+04   29601.000000   29601.000000   29601.000000
# mean   4.680320e+04   43122.554204   40235.545184   38858.449816
# std    6.912389e+04   64196.383913   60699.344884   59519.893043
# min   -1.572640e+05 -170000.000000  -81334.000000 -339603.000000
# ...

# %%
# Box plots for numerical features
numerical_features = ['LIMIT_BAL', 'AGE', 'BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6']
plt.figure(figsize=(12, 8))
data[numerical_features].boxplot()
plt.title('Box Plot of Numerical Features')
plt.xticks(rotation=45)
plt.show()

# %%
# Histograms for numerical features
data[numerical_features].hist(bins=20, figsize=(14, 10), layout=(3, 3))
plt.suptitle('Histograms of Numerical Features')
plt.show()

# %%
# Grouped statistics by default status
grouped_stats = data.groupby('default_payment_next_month').mean()
print(grouped_stats)
# Out:
#                                 LIMIT_BAL        AGE    BILL_AMT1  \
# default_payment_next_month
# 0                           178299.965211  35.392851  51716.43912
# 1                           130125.311128  35.712036  48314.86919
#
#                                BILL_AMT2     BILL_AMT3     BILL_AMT4  \
# default_payment_next_month
# 0                           49463.303966  47303.106975  43448.517133
# 1                           47127.875095  45062.736109  41987.680091
#
#                                BILL_AMT5     BILL_AMT6     PAY_AMT1  \
# default_payment_next_month
# 0                           40438.090233  39028.741129  6305.575317
# 1                           39530.363361  38265.562755  3365.575322
#
#                                PAY_AMT2     PAY_AMT3     PAY_AMT4  \
# default_payment_next_month
# 0                           6616.275657  5728.758915  5308.696860
# 1                           3382.854807  3351.971083  3157.358062
#
# ...

# %%
# Correlation Analysis
print("\nCorrelation analysis:")
corr_matrix = data.corr()
print(corr_matrix)
# Out:
# Correlation analysis:
#            LIMIT_BAL       AGE  BILL_AMT1  BILL_AMT2  BILL_AMT3  BILL_AMT4  \
# LIMIT_BAL   1.000000  0.144214   0.283695   0.276673   0.281738   0.293442
# AGE         0.144214  1.000000   0.054704   0.052385   0.051839   0.049839
# BILL_AMT1   0.283695  0.054704   1.000000   0.951255   0.891886   0.861238
# BILL_AMT2   0.276673  0.052385   0.951255   1.000000   0.927801   0.893418
# BILL_AMT3   0.281738  0.051839   0.891886   0.927801   1.000000   0.925094
# BILL_AMT4   0.293442  0.049839   0.861238   0.893418   0.925094   1.000000
# BILL_AMT5   0.295316  0.048323   0.831406   0.861465   0.885669   0.940458
# BILL_AMT6   0.289701  0.046712   0.804834   0.833846   0.855571   0.902348
# PAY_AMT1    0.195666  0.025440   0.140489   0.280903   0.244564   0.233241
# PAY_AMT2    0.177669  0.022402   0.098947   0.100613   0.318039   0.208175
# PAY_AMT3    0.210523  0.029478   0.156813   0.151052   0.131112   0.300270
# ...

# %%
# Plotting the correlation matrix
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, annot=True, fmt='.2f', cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
from scipy.stats import ttest_ind, chi2_contingency, pearsonr


# T-test: Compare the means of LIMIT_BAL for default and non-default groups
default_group = data[data['default_payment_next_month'] == 1]['LIMIT_BAL']
non_default_group = data[data['default_payment_next_month'] == 0]['LIMIT_BAL']
t_stat, p_value = ttest_ind(default_group, non_default_group)
print(f'T-test: t-statistic = {t_stat}, p-value = {p_value}')
# Out:
# T-test: t-statistic = -26.87823364745018, p-value = 3.057212606548002e-157

# %%
# Chi-Square Test: Test the independence of SEX and default_payment_next_month
contingency_table = pd.crosstab(data['SEX'], data['default_payment_next_month'])
chi2, p, dof, expected = chi2_contingency(contingency_table)
print(f'Chi-Square Test: chi2 = {chi2}, p-value = {p}')
# Out:
# Chi-Square Test: chi2 = 46.729040463318896, p-value = 8.151208643603006e-12

# %%
# Correlation Analysis: Pearson correlation between LIMIT_BAL and AGE
corr, _ = pearsonr(data['LIMIT_BAL'], data['AGE'])
print(f'Pearson Correlation: correlation coefficient = {corr}')
# Out:
# Pearson Correlation: correlation coefficient = 0.1442144509415449

# %%
# Count the number of males and females in the dataset
sex_counts = data['SEX'].value_counts()
# Map numerical values to labels
sex_counts.index = sex_counts.index.map({1: 'Male', 2: 'Female'})
# Plotting the proportions using a pie chart
plt.figure(figsize=(8, 8))
plt.pie(sex_counts, labels=sex_counts.index, autopct='%1.1f%%', colors=['#4DAF4A', '#377EB8'], startangle=90)
plt.title('Proportion of Male and Female Clients', fontsize=16)
plt.axis('equal')  # Equal aspect ratio ensures the pie chart is circular.
plt.show()

# %% [markdown]
# The pie chart shows gender distribution of 60.3% females and 39.7% males

# %%
import matplotlib.pyplot as plt
import seaborn as sns


# Set the figure size and style
plt.figure(figsize=(12, 6))
sns.set(style="whitegrid")

# Create the count plot
ax = sns.countplot(data=data, x='SEX', hue='default_payment_next_month' , palette='rocket')

# Set the labels and title
plt.xlabel("Sex", fontsize=12)
plt.ylabel("# of Clients", fontsize=12)
plt.title("Distribution of Clients by Sex and Default Status", fontsize=14)
plt.ylim(0, 20000)
plt.xticks(ticks=[0, 1], labels=['Male', 'Female'], fontsize=11)

# Annotate the bars with their counts
for p in ax.patches:
    ax.annotate(
        format(p.get_height(), ','),
        (p.get_x() + p.get_width() / 2., p.get_height()),
        ha='center',
        va='center',
        xytext=(0, 5),
        textcoords='offset points',
        fontsize=10,
        color='black'
    )

# Add a legend and show the plot
plt.legend(title='Default Payment Next Month', title_fontsize='13', fontsize='11')
plt.show()

# %%
# Pair plot of selected features ('LIMIT_BAL', 'AGE', 'BILL_AMT1', 'PAY_AMT1', 'default_payment_next_month')
selected_features = ['LIMIT_BAL', 'AGE', 'BILL_AMT1', 'PAY_AMT1', 'default_payment_next_month']
sns.pairplot(data[selected_features], hue='default_payment_next_month')
plt.show()

# %%
# Ploting the relationship between age and default payment next month using BoxPlot
plt.figure(figsize=(10, 6))
sns.boxplot(x='default_payment_next_month', y='AGE', data=data)
plt.title('Relationship between Age and Default Payment Next Month')
plt.xlabel('Default Payment Next Month (1 = Yes, 0 = No)')
plt.ylabel('Age')
plt.show()

# %%
# Ploting Distribution of Age
plt.figure(figsize=(10, 6))
sns.histplot(data['AGE'], bins=30, kde=True)
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
# Counts of default and non-default payments
default_counts = data['default_payment_next_month'].value_counts()

# Ploting the pie chart for the Proportion of Default and Non-default Payments
labels = ['Non-default', 'Default']
colors = ['#66b3ff', '#ffcc99']
explode = (0, 0.1)  # explode the 2nd slice (i.e. 'Default')

plt.figure(figsize=(8, 8))
plt.pie(default_counts, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140, explode=explode)
plt.title('Proportion of Default and Non-default Payments')
plt.show()

# %%
# Mapping the education levels to their descriptions
education_mapping = {1: 'Graduate School', 2: 'University', 3: 'High School', 4: 'Others'}
data['EDUCATION_MAP'] = data['EDUCATION'].map(education_mapping)

# %%
# Ploting the relationship between education and default payment next month using bargraph
plt.figure(figsize=(10, 6))
sns.countplot(x='EDUCATION_MAP', hue='default_payment_next_month', data=data, palette='Set2')
plt.title('Relationship between Education Level and Default Payment Next Month')
plt.xlabel('Education Level')
plt.ylabel('Count')
plt.legend(title='Default Payment Next Month', labels=['No', 'Yes'])
plt.xticks(rotation=45)
plt.show()

# %%
# Ploting the relationship between LIMIT_BAL and default payment next month using boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(x='default_payment_next_month', y='LIMIT_BAL', data=data, palette='Set2')
plt.title('Relationship between Credit Limit (LIMIT_BAL) and Default Payment Next Month')
plt.xlabel('Default Payment Next Month')
plt.ylabel('Credit Limit (NT dollars)')
plt.xticks([0, 1], ['No', 'Yes'])
plt.show()

# %%
# Ploting Relationship between Education and Credit Limit using a boxplot
plt.figure(figsize=(10, 6))
sns.boxplot(x='EDUCATION_MAP', y='LIMIT_BAL', data=data, palette='Set2')
plt.title('Relationship between Education and Credit Limit')
plt.xlabel('Education Level')
plt.ylabel('Credit Limit (LIMIT_BAL)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Mapping for marital status
marriage_map = {
    1: 'Married',
    2: 'Single',
    3: 'Others'
}

# Apply the marital status mapping
data['MARRIAGE_MAP'] = data['MARRIAGE'].map(marriage_map)

# %%
# Plotting relationship between MARRIAGE and default_payment_next_month

plt.figure(figsize=(10, 6))

# Count plot to show distribution of default_payment_next_month across MARRIAGE categories
sns.countplot(x='MARRIAGE_MAP', hue='default_payment_next_month', data=data, palette='Set1')
plt.title('Relationship between Marital Status and Default Payment Next Month')
plt.xlabel('Marital Status')
plt.ylabel('Count')
plt.legend(title='Default Payment Next Month', loc='upper right', labels=['No', 'Yes'])
plt.tight_layout()
plt.show()

# %%
# Selecting columns related to repayment status (PAY_1 to PAY_)
repayment_columns = ['PAY_1', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6']

# Flatten and count the values across all repayment columns
payment_status_counts = data[repayment_columns].stack().value_counts().sort_index()

# Mapping numeric codes to descriptive labels
payment_labels = {
    -2: 'No Consumption',
    -1: 'Pay Duly',
     0: 'Revolving Credit',
     1: 'Delay 1 Month',
     2: 'Delay 2 Months',
     3: 'Delay 3 Months',
     4: 'Delay 4 Months',
     5: 'Delay 5 Months',
     6: 'Delay 6 Months',
     7: 'Delay 7 Months',
     8: 'Delay 8 Months',
     9: 'Delay 9+ Months'
}

# Create a DataFrame for plotting
plot_data = pd.DataFrame({
    'Repayment Status': payment_status_counts.index.map(payment_labels),
    'Count': payment_status_counts.values
})

# Plotting the bar plot for the Distribution of Repayment Status Across Months
plt.figure(figsize=(12, 6))
sns.barplot(x='Repayment Status', y='Count', data=plot_data, palette='Set1', order=payment_labels.values())
plt.title('Distribution of Repayment Status Across Months')
plt.xlabel('Repayment Status')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Selecting columns related to payment status (PAY_0 to PAY_6) and default_payment_next_month
payment_columns = ['PAY_1', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6']
target_column = 'default_payment_next_month'

# Plotting grouped bar plot to visualize relationship between PAY and default_payment_next_month
plt.figure(figsize=(12, 6))

# Iterate through each payment column and plot the grouped bar
for i, col in enumerate(payment_columns, start=1):
    plt.subplot(2, 3, i)
    sns.countplot(x=col, hue=target_column, data=data, palette='Set1')
    plt.title(f'{col} vs Default Payment Next Month')
    plt.xlabel(f'{col} Payment Status')
    plt.ylabel('Count')
    plt.legend(title='Default Payment Next Month', labels=['No', 'Yes'])
    plt.tight_layout()

plt.show()

# %%
# List of bill amount and payment amount columns
bill_columns = ['BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6']
pay_columns = ['PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6']

# Creating scatter plots for each pair of bill amounts and payment amounts
plt.figure(figsize=(15, 10))

for i in range(6):
    plt.subplot(2, 3, i + 1)
    sns.scatterplot(x=data[bill_columns[i]], y=data[pay_columns[i]], alpha=0.5)
    plt.title(f'Relationship between {bill_columns[i]} and {pay_columns[i]}')
    plt.xlabel('Bill Amount (NT dollars)')
    plt.ylabel('Payment Amount (NT dollars)')

plt.tight_layout()
plt.show()

# %%
# Set up the figure size
plt.figure(figsize=(20, 5))

# First subplot for LIMIT_BAL distribution
plt.subplot(1, 2, 1)
sns.histplot(data['LIMIT_BAL'], kde=True)  # kde=True adds the KDE line

# Second subplot for AGE distribution
plt.subplot(1, 2, 2)
sns.histplot(data['AGE'], kde=True)

# Display the plots
plt.show()

# %% [markdown]
# Plotting the continuous variables reveals that the dataset is skewed with respect to the age of the clients and the limiting balance.
# Many of our clients have limiting balances ranging from 0 to 200000 currency.
# We have a greater number of clientele in the 20–40 age range, or mostly in the young to mid–aged groups.
# Below, we will examine how various factors affect the target variable.

# %%
# Assuming the DataFrame 'defaulters' is already loaded and contains the relevant data
# Define age bins and labels
bins = [20, 30, 40, 50, 60, 70, 80]
names = ['21-30', '31-40', '41-50', '51-60', '61-70', '71-80']
data['AGE_BIN'] = pd.cut(x=data['AGE'], bins=bins, labels=names, right=True)

# Count the number of non-defaulters and defaulters in each age group
age_0 = data[data['default_payment_next_month'] == 0]['AGE_BIN'].value_counts().reindex(names, fill_value=0)
age_1 = data[data['default_payment_next_month'] == 1]['AGE_BIN'].value_counts().reindex(names, fill_value=0)

# Plotting the data
plt.figure(figsize=(12, 6))
bar_width = 0.35
index = range(len(names))

# Plotting bars for non-defaulters and defaulters
plt.bar([i - bar_width/2 for i in index], age_0.values, width=bar_width, label='Non-defaulters (0)', color='blue')
plt.bar([i + bar_width/2 for i in index], age_1.values, width=bar_width, label='Defaulters (1)', color='red')

# Adding text labels on the bars for clarity
for i, (x, y) in enumerate(zip(index, age_0.values)):
    plt.text(x - bar_width/2, y, y, ha='center', va='bottom', fontsize=12)
for i, (x, y) in enumerate(zip(index, age_1.values)):
    plt.text(x + bar_width/2, y, y, ha='center', va='bottom', fontsize=12)

# Labeling the plot
plt.xticks(index, names, fontsize=12)
plt.yticks(fontsize=12)
plt.xlabel('Age Group', fontsize=14)
plt.ylabel('Number of Clients', fontsize=14)
plt.title('Number of Defaulters and Non-defaulters in Each Age Group', fontsize=16)
plt.legend(loc='upper right', fontsize=12)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# Our maximum customer is in the age range of 21–30, then 31–40. Therefore, the number of clients who would miss their payments the following month is declining as the age group grows. Thus, age is a significant factor in determining the default payment for the following month.

# %%
# Create a figure with a specified size
fig, axes = plt.subplots(figsize=(20, 10))

# Remove any existing axes before creating new subplots
if plt.gca() in plt.get_fignums():
    plt.gca().remove()

# Scatter plot for PAY_AMT1 vs BILL_AMT1
ax1 = plt.subplot(231)
plt.scatter(x=data.PAY_AMT1, y=data.BILL_AMT1, c='r', s=1)
plt.title('Payment vs. Bill Amount - Month 1', fontsize=15)
plt.xlabel('Payment Amount', fontsize=12)
plt.ylabel('Bill Amount', fontsize=12)

# Scatter plot for PAY_AMT2 vs BILL_AMT2
ax2 = plt.subplot(232)
plt.scatter(x=data.PAY_AMT2, y=data.BILL_AMT2, c='b', s=1)
plt.title('Payment vs. Bill Amount - Month 2', fontsize=15)
plt.xlabel('Payment Amount', fontsize=12)

# Scatter plot for PAY_AMT3 vs BILL_AMT3
ax3 = plt.subplot(233)
plt.scatter(x=data.PAY_AMT3, y=data.BILL_AMT3, c='g', s=1)
plt.title('Payment vs. Bill Amount - Month 3', fontsize=15)
plt.xlabel('Payment Amount', fontsize=12)

# Scatter plot for PAY_AMT4 vs BILL_AMT4
ax4 = plt.subplot(234)
plt.scatter(x=data.PAY_AMT4, y=data.BILL_AMT4, c='c', s=1)
plt.title('Payment vs. Bill Amount - Month 4', fontsize=15)
plt.xlabel('Payment Amount', fontsize=12)
plt.ylabel('Bill Amount in Past 6 Months', fontsize=15)

# Scatter plot for PAY_AMT5 vs BILL_AMT5
ax5 = plt.subplot(235)
plt.scatter(x=data.PAY_AMT5, y=data.BILL_AMT5, c='y', s=1)
plt.title('Payment vs. Bill Amount - Month 5', fontsize=15)
plt.xlabel('Payment Amount in Past 6 Months', fontsize=15)

# Scatter plot for PAY_AMT6 vs BILL_AMT6
ax6 = plt.subplot(236)
plt.scatter(x=data.PAY_AMT6, y=data.BILL_AMT6, c='m', s=1)
plt.title('Payment vs. Bill Amount - Month 6', fontsize=15)
plt.xlabel('Payment Amount', fontsize=12)

# Display the plots
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Emmanuel\AppData\Local\Temp\ipykernel_9308\2544133545.py:9: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   ax1 = plt.subplot(231)

# %% [markdown]
# According to the above plot, a greater percentage of clients have large bills yet make very little payment towards them. With the largest number of datapoints closely packed along the Y-axis near 0 on the X-axis, we can conclude this.

# %% [markdown]
# # Model Implementation

# %%
#pip install gplearn

# %%
# Drop the EDUCATION_MAP, MARRIAGE_MAP and AGE_BIN columns as it is not relevant for model
data = data.drop(columns=['EDUCATION_MAP','MARRIAGE_MAP', 'AGE_BIN'])

# %%
data
# Out:
#        LIMIT_BAL SEX EDUCATION MARRIAGE  AGE PAY_1 PAY_2 PAY_3 PAY_4 PAY_5  \
# 0          20000   2         2        1   24     2     2    -1    -1    -2
# 1         120000   2         2        2   26    -1     2     0     0     0
# 2          90000   2         2        2   34     0     0     0     0     0
# 3          50000   2         2        1   37     0     0     0     0     0
# 4          50000   1         2        1   57    -1     0    -1     0     0
# ...          ...  ..       ...      ...  ...   ...   ...   ...   ...   ...
# 29995     220000   1         3        1   39     0     0     0     0     0
# 29996     150000   1         3        2   43    -1    -1    -1    -1     0
# 29997      30000   1         2        2   37     4     3     2    -1     0
# 29998      80000   1         3        1   41     1    -1     0     0     0
# 29999      50000   1         2        1   46     0     0     0     0     0
#
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
# Separate numeric and categorical columns
numeric_columns = data.select_dtypes(include=['int64', 'float64']).columns
categorical_columns = data.select_dtypes(include=['object']).columns

# Exclude categorical columns from normalization
non_normalizable_columns = list(categorical_columns)
columns_to_normalize = [col for col in numeric_columns if col not in non_normalizable_columns]

# Initialize MinMaxScaler
scaler = MinMaxScaler()

# Normalize specified numeric columns
data[columns_to_normalize] = scaler.fit_transform(data[columns_to_normalize])

# Print the DataFrame to verify normalization
print(data)
# Out:
#        LIMIT_BAL SEX EDUCATION MARRIAGE       AGE PAY_1 PAY_2 PAY_3 PAY_4  \
# 0       0.010101   2         2        1  0.051724     2     2    -1    -1
# 1       0.111111   2         2        2  0.086207    -1     2     0     0
# 2       0.080808   2         2        2  0.224138     0     0     0     0
# 3       0.040404   2         2        1  0.275862     0     0     0     0
# 4       0.040404   1         2        1  0.620690    -1     0    -1     0
# ...          ...  ..       ...      ...       ...   ...   ...   ...   ...
# 29995   0.212121   1         3        1  0.310345     0     0     0     0
# 29996   0.141414   1         3        2  0.379310    -1    -1    -1    -1
# 29997   0.020202   1         2        2  0.275862     4     3     2    -1
# 29998   0.070707   1         3        1  0.344828     1    -1     0     0
# 29999   0.040404   1         2        1  0.431034     0     0     0     0
#
#       PAY_5  ... BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# ...

# %%
columns_to_normalize
# Out:
# ['LIMIT_BAL',
#  'AGE',
#  'BILL_AMT1',
#  'BILL_AMT2',
#  'BILL_AMT3',
#  'BILL_AMT4',
#  'BILL_AMT5',
#  'BILL_AMT6',
#  'PAY_AMT1',
#  'PAY_AMT2',
#  'PAY_AMT3',
#  'PAY_AMT4',
#  'PAY_AMT5',
#  'PAY_AMT6']

# %%
data
# Out:
#        LIMIT_BAL SEX EDUCATION MARRIAGE       AGE PAY_1 PAY_2 PAY_3 PAY_4  \
# 0       0.010101   2         2        1  0.051724     2     2    -1    -1
# 1       0.111111   2         2        2  0.086207    -1     2     0     0
# 2       0.080808   2         2        2  0.224138     0     0     0     0
# 3       0.040404   2         2        1  0.275862     0     0     0     0
# 4       0.040404   1         2        1  0.620690    -1     0    -1     0
# ...          ...  ..       ...      ...       ...   ...   ...   ...   ...
# 29995   0.212121   1         3        1  0.310345     0     0     0     0
# 29996   0.141414   1         3        2  0.379310    -1    -1    -1    -1
# 29997   0.020202   1         2        2  0.275862     4     3     2    -1
# 29998   0.070707   1         3        1  0.344828     1    -1     0     0
# 29999   0.040404   1         2        1  0.431034     0     0     0     0
#
#       PAY_5  ... BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from gplearn.genetic import SymbolicClassifier






# Define features and target
X = data.drop('default_payment_next_month', axis=1)
y = data['default_payment_next_month']

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Define the symbolic regression model using Genetic Programming
gp = SymbolicClassifier(population_size=1000,
                        generations=80,
                        tournament_size=7,
                        const_range=(0, 1),
                        init_depth=(2, 6),
                        init_method='half and half', 
                        parsimony_coefficient=0.001,
                        random_state=42)

# Fit the model
gp.fit(X_train, y_train)

# Make predictions
y_pred = gp.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")
print("Classification Report:")
print(classification_report(y_test, y_pred))

# Print the best program found
print("Best program:")
print(gp._program)
# Out:
# Accuracy: 0.81
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.96      0.89      6859
#            1       0.69      0.32      0.44      2022
#
#     accuracy                           0.81      8881
#    macro avg       0.76      0.64      0.66      8881
# weighted avg       0.80      0.81      0.79      8881
#
# Best program:
# sub(sub(sub(X5, X16), X16), 0.919)

# %%
from sklearn.metrics import confusion_matrix

# Compute confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Create a heatmap
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=['Not Default', 'Default'], 
            yticklabels=['Not Default', 'Default'])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

# %%
from sklearn.metrics import roc_curve, roc_auc_score

# Compute ROC curve and AUC
fpr, tpr, _ = roc_curve(y_test, gp.predict_proba(X_test)[:, 1])
auc_score = roc_auc_score(y_test, gp.predict_proba(X_test)[:, 1])

# Plot ROC curve
plt.figure(figsize=(10, 7))
plt.plot(fpr, tpr, marker='o', label='ROC curve (AUC = %0.2f)' % auc_score)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc='best')
plt.show()

# %%
from sklearn.metrics import precision_recall_curve

# Compute Precision-Recall curve
precision, recall, _ = precision_recall_curve(y_test, gp.predict_proba(X_test)[:, 1])

# Plot Precision-Recall curve
plt.figure(figsize=(10, 7))
plt.plot(recall, precision, marker='o', label='Precision-Recall curve')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc='best')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from gplearn.genetic import SymbolicClassifier
import random



# Define features and target
X = data.drop('default_payment_next_month', axis=1)
y = data['default_payment_next_month']

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize variables to store MSE values
mse_values = []

# Run the model 50 times
for i in range(50):
    # Generate a random state number between 0 and 1000.
    random_state = random.randint(0, 1000)
    
    # Define the symbolic regression model using Genetic Programming
    gp = SymbolicClassifier(population_size=1000,
                            generations=80,
                            tournament_size=7,
                            const_range=(0, 1),
                            init_depth=(2, 6),
                            init_method='half and half', 
                            parsimony_coefficient=0.001,
                            random_state=random_state)

    # Fit the model
    gp.fit(X_train, y_train)

    # Make predictions
    y_pred = gp.predict(X_test)

    # Calculate MSE for each generation
    mse = mean_squared_error(y_test, y_pred)
    mse_values.append(mse)
    
    # Print the random state and MSE value
    print(f"Run {i+1}: Random State = {random_state}, MSE = {mse:.4f}")
# Out:
# Run 1: Random State = 639, MSE = 0.1873
# Run 2: Random State = 96, MSE = 0.1873
# Run 3: Random State = 175, MSE = 0.1873
# Run 4: Random State = 765, MSE = 0.1873
# Run 5: Random State = 894, MSE = 0.2165
# Run 6: Random State = 25, MSE = 0.1873
# Run 7: Random State = 541, MSE = 0.1873
# Run 8: Random State = 20, MSE = 0.2026
# Run 9: Random State = 614, MSE = 0.1880
# Run 10: Random State = 101, MSE = 0.1873
# Run 11: Random State = 156, MSE = 0.2026
# Run 12: Random State = 448, MSE = 0.1880
# Run 13: Random State = 314, MSE = 0.1873
# Run 14: Random State = 137, MSE = 0.2026
# Run 15: Random State = 558, MSE = 0.1873
# Run 16: Random State = 250, MSE = 0.2026
# Run 17: Random State = 913, MSE = 0.1873
# Run 18: Random State = 321, MSE = 0.1873
# Run 19: Random State = 777, MSE = 0.1889
# Run 20: Random State = 819, MSE = 0.1873
# Run 21: Random State = 539, MSE = 0.1873
# Run 22: Random State = 699, MSE = 0.1873
# Run 23: Random State = 708, MSE = 0.1892
# ...

# %%
# Plot MSE values vs. generations
plt.figure(figsize=(10, 6))
plt.plot(range(1, 51), mse_values, marker='o')
plt.title('MSE Values vs. Generations')
plt.xlabel('Generation')
plt.ylabel('Mean Squared Error')
plt.grid(True)
plt.show()
